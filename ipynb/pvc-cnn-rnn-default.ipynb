# %% [markdown]
# # Preprocessing & Segmentation

# %%
import numpy as np
import pandas as pd
import os
import joblib
import warnings
from scipy.signal import find_peaks, butter, filtfilt
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

# %%
DATA_DIR = "/kaggle/input/ecg-data"
LABEL_FILE = "/kaggle/input/diagnosis/Diagnosis.xlsx"

OUTPUT_DIR = "/kaggle/working"

OUTPUT_X = os.path.join(OUTPUT_DIR, "X_preprocessed.npy")
OUTPUT_Y = os.path.join(OUTPUT_DIR, "y_preprocessed.npy")
LABEL_ENCODER_FILE = os.path.join(OUTPUT_DIR, "label_encoder_location.joblib")

# %%
SAMPLING_RATE = 500 # Hz
WINDOW_BEFORE_R = 300 
WINDOW_AFTER_R = 700  
TOTAL_WINDOW = WINDOW_BEFORE_R + WINDOW_AFTER_R # 1000 samples

# BANDPASS FILTER PARAMETERS
LOWCUT = 0.5
HIGHCUT = 40.0
FILTER_ORDER = 2

print("="*80)
print("ECG PREPROCESSING: RAW CSV -> BANDPASS -> SEGMENTED NPY")
print("="*80)
# Out:
# ================================================================================
# ECG PREPROCESSING: RAW CSV -> BANDPASS -> SEGMENTED NPY
# ================================================================================

# %%
def load_labels(label_file):
    print(f"Loading labels from: {label_file}")
    df = pd.read_excel(label_file)
    
    # Mapping Diagnosis ke 4 Kelas Utama
    class_mapping = {
        # Left Ventricular Region
        "Left_AMC": "Left_Ventricular_Region",
        "Left_LCC": "Left_Ventricular_Region", 
        "Left_RCC": "Left_Ventricular_Region",
        "Left_Summit": "Left_Ventricular_Region",
        
        # Right Ventricular Region
        "Right_LC": "Right_Ventricular_Region",
        "Right_RC": "Right_Ventricular_Region", 
        "Right_AC": "Right_Ventricular_Region",
        "Right_FreeWall": "Right_Ventricular_Region",
        
        # Outflow Tract Region
        "Right_RVOTOther": "Outflow_Tract_Region",
        "Left_LCC-RCC Ommisure": "Outflow_Tract_Region",
        
        # Septal Region
        "Right_PosteriorSeptal": "Septal_Region",
        "Right_AnteriorSeptal": "Septal_Region"
    }
    
    # Deteksi kolom diagnosis
    target_col = None
    if 'Diagnosis' in df.columns: target_col = 'Diagnosis'
    elif 'diagnosis' in df.columns: target_col = 'diagnosis'
    
    # Cek format kompleks (LeftRight + Sublocation)
    if 'LeftRight' in df.columns and 'Sublocation' in df.columns:
        print("Mendeteksi format kolom 'LeftRight' + 'Sublocation'")
        df['Full_Location'] = df['LeftRight'].astype(str) + '_' + df['Sublocation'].astype(str)
        df['Class'] = df['Full_Location'].map(class_mapping)
    elif target_col:
        print(f"Menggunakan kolom '{target_col}'")
        df['Class'] = df[target_col].map(class_mapping)
    else:
        raise ValueError("Tidak dapat menemukan kolom diagnosis yang valid di Excel!")
    
    # Drop yang tidak punya kelas valid
    df = df.dropna(subset=['Class'])
    print(f"Total pasien valid dengan label: {len(df)}")
    print(df['Class'].value_counts())
    
    return df

# %%
def apply_bandpass_filter(data, lowcut, highcut, fs, order=2):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype='band')
    # Apply filter to each channel (axis 0 is time, axis 1 is channels)
    # filtfilt applies backward-forward filter to avoid phase shift
    y = filtfilt(b, a, data, axis=0) 
    return y

def normalize_signal(signal):
    # Z-Score Normalization per lead
    mean = np.mean(signal, axis=0)
    std = np.std(signal, axis=0)
    std[std == 0] = 1
    return (signal - mean) / std

def segment_ecg(signal, fs=500):
    # Gunakan RMS untuk deteksi peak
    rms = np.sqrt(np.mean(signal**2, axis=1))
    
    # Normalize RMS
    rms_norm = (rms - np.mean(rms)) / (np.std(rms) + 1e-8)
    
    # Find Peaks
    min_dist = int(0.6 * fs) # 600ms min distance
    peaks, _ = find_peaks(rms_norm, distance=min_dist, height=0.5, prominence=0.5)
    
    segments = []
    for peak in peaks:
        start = peak - WINDOW_BEFORE_R
        end = peak + WINDOW_AFTER_R
        
        if start >= 0 and end <= len(signal):
            seg = signal[start:end, :]
            if len(seg) == TOTAL_WINDOW:
                segments.append(seg)
                
    return segments

# %%
def process_files(data_dir, df_labels):
    X_all = []
    y_all = []
    
    files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]
    print(f"Ditemukan {len(files)} file CSV di {data_dir}")
    
    success_count = 0
    
    for i, fname in enumerate(files):
        if (i+1)%50 == 0: print(f"Processing {i+1}/{len(files)}...")
        
        try:
            pid = int(os.path.splitext(fname)[0])
        except:
            continue
            
        label_row = None
        if 'HospitalID' in df_labels.columns:
            label_row = df_labels[df_labels['HospitalID'] == pid]
        else:
            col1 = df_labels.columns[0]
            label_row = df_labels[df_labels[col1] == pid]
            
        if len(label_row) == 0:
            continue 
            
        label_class = label_row['Class'].values[0]
        
        path = os.path.join(data_dir, fname)
        try:
            df_ecg = pd.read_csv(path)
            data = df_ecg.select_dtypes(include=[np.number]).values
            if data.shape[1] > 12: data = data[:, :12] 
            
            # 1. BANDPASS FILTER
            data_filt = apply_bandpass_filter(data, LOWCUT, HIGHCUT, SAMPLING_RATE, FILTER_ORDER)
            
            # 2. NORMALISASI
            data_norm = normalize_signal(data_filt)
            
            # 3. SEGMENTASI
            segments = segment_ecg(data_norm)
            
            if len(segments) > 0:
                X_all.extend(segments)
                y_all.extend([label_class] * len(segments))
                success_count += 1
                
        except Exception as e:
            print(f"Error processing {fname}: {e}")
            continue

    print(f"\nSelesai! Berhasil memproses {success_count} file pasien.")
    return np.array(X_all), np.array(y_all)

# %%
# UTAMA
if __name__ == "__main__":
    if not os.path.exists(DATA_DIR):
        print(f"ERROR: Folder data tidak ditemukan di {DATA_DIR}")
        exit()
        
    df_labels = load_labels(LABEL_FILE)
    X, y = process_files(DATA_DIR, df_labels)
    
    print(f"\nShape Data: {X.shape}")
    print(f"Shape Label: {y.shape}")
    
    # Encoding Label
    le = LabelEncoder()
    y_enc = le.fit_transform(y)
    
    # Save Label Encoder
    joblib.dump(le, LABEL_ENCODER_FILE)
    print(f"Label encoder disimpan ke {LABEL_ENCODER_FILE}")
    print(f"Kelas: {le.classes_}")
    
    # Save NPY
    np.save(OUTPUT_X, X)
    np.save(OUTPUT_Y, y_enc)
    print(f"Data disimpan ke:\n  {OUTPUT_X}\n  {OUTPUT_Y}")
    
    print("\nSIAP! Sekarang jalankan 'python RUN_ALL_COMPLETE.py'")
# Out:
# Loading labels from: /kaggle/input/diagnosis/Diagnosis.xlsx
# Mendeteksi format kolom 'LeftRight' + 'Sublocation'
# Total pasien valid dengan label: 294
# Class
# Right_Ventricular_Region    152
# Left_Ventricular_Region      69
# Septal_Region                60
# Outflow_Tract_Region         13
# Name: count, dtype: int64
# Ditemukan 334 file CSV di /kaggle/input/ecg-data
# Processing 50/334...
# Processing 100/334...
# Processing 150/334...
# Processing 200/334...
# Processing 250/334...
# Processing 300/334...
#
# Selesai! Berhasil memproses 294 file pasien.
#
# Shape Data: (5256, 1000, 12)
# Shape Label: (5256,)
# Label encoder disimpan ke /kaggle/working/label_encoder_location.joblib
# Kelas: ['Left_Ventricular_Region' 'Outflow_Tract_Region'
#  'Right_Ventricular_Region' 'Septal_Region']
# Data disimpan ke:
#   /kaggle/working/X_preprocessed.npy
#   /kaggle/working/y_preprocessed.npy
#
# SIAP! Sekarang jalankan 'python RUN_ALL_COMPLETE.py'

# %% [markdown]
# # Model CNN - RNN Default

# %%
import numpy as np
import pandas as pd
import os, time, warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import *
from sklearn.preprocessing import label_binarize
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from collections import Counter

np.random.seed(42)
tf.random.set_seed(42)
# Out:
# 2026-02-01 16:46:26.415320: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769964386.597122      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769964386.647681      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769964387.086836      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769964387.086865      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769964387.086868      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769964387.086871      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
print("="*80)
print("CNN-RNN + ATTENTION dengan GAN ECG 1D")
print("Output Lengkap - 13 Files")
print("="*80)

# HYPERPARAMETERS
RNN_UNITS = 128
DROPOUT = 0.3
DROPOUT_DENSE = 0.5
LR = 0.001
BATCH = 32
EPOCHS = 50
FOLDS = 5

# GAN PARAMETERS
LATENT_DIM = 100
GAN_EPOCHS = 500
GAN_BATCH = 32
# Out:
# ================================================================================
# CNN-RNN + ATTENTION dengan GAN ECG 1D
# Output Lengkap - 13 Files
# ================================================================================

# %%
class AttentionLayer(keras.layers.Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)
    def build(self, input_shape):
        self.W = self.add_weight(name='attention_weight',
                                 shape=(input_shape[-1], input_shape[-1]),
                                 initializer='glorot_uniform',
                                 trainable=True)
        self.b = self.add_weight(name='attention_bias',
                                 shape=(input_shape[-1],),
                                 initializer='zeros',
                                 trainable=True)
        super(AttentionLayer, self).build(input_shape)
    def call(self, inputs):
        e = tf.nn.tanh(tf.tensordot(inputs, self.W, axes=1) + self.b)
        a = tf.nn.softmax(e, axis=1)
        return tf.reduce_sum(inputs * a, axis=1)

# %%
# ====================== UTILITY FUNCTIONS ======================
def plot_confusion_matrix_complete(y_true, y_pred, classes, filename, title):
    """Plot confusion matrix lengkap"""
    cm = confusion_matrix(y_true, y_pred)
    acc = accuracy_score(y_true, y_pred)
    
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, yticklabels=classes)
    plt.title(f'{title}\nAccuracy: {acc:.4f}', fontsize=16, fontweight='bold', pad=20)
    plt.ylabel('True Label', fontsize=14, fontweight='bold')
    plt.xlabel('Predicted Label', fontsize=14, fontweight='bold')
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()
    
    return cm, acc

def plot_roc_curve_complete(y_true, y_pred_probs, classes, filename, title):
    """Plot ROC curve untuk semua kelas"""
    n_classes = len(classes)
    y_true_bin = label_binarize(y_true, classes=range(n_classes))
    
    plt.figure(figsize=(10, 8))
    
    # Compute ROC curve and AUC for each class
    fpr, tpr, roc_auc = {}, {}, {}
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    
    # Plot all ROC curves
    colors = plt.cm.Set1(np.linspace(0, 1, n_classes))
    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=2,
                 label=f'{classes[i]} (AUC = {roc_auc[i]:.3f})')
    
    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=12, fontweight='bold')
    plt.ylabel('True Positive Rate', fontsize=12, fontweight='bold')
    plt.title(f'{title}\nROC Curves', fontsize=14, fontweight='bold')
    plt.legend(loc="lower right", fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()

# %%
def plot_learning_curve_complete(history, filename):
    """Plot learning curve dari training history"""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    
    # Plot accuracy
    ax1.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
    ax1.plot(history.history['val_accuracy'], label='Val Accuracy', linewidth=2)
    ax1.set_title('Model Accuracy', fontsize=14, fontweight='bold')
    ax1.set_xlabel('Epoch', fontsize=12, fontweight='bold')
    ax1.set_ylabel('Accuracy', fontsize=12, fontweight='bold')
    ax1.legend(fontsize=10)
    ax1.grid(True, alpha=0.3)
    
    # Plot loss
    ax2.plot(history.history['loss'], label='Train Loss', linewidth=2)
    ax2.plot(history.history['val_loss'], label='Val Loss', linewidth=2)
    ax2.set_title('Model Loss', fontsize=14, fontweight='bold')
    ax2.set_xlabel('Epoch', fontsize=12, fontweight='bold')
    ax2.set_ylabel('Loss', fontsize=12, fontweight='bold')
    ax2.legend(fontsize=10)
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()

def plot_tsne_complete(model, X_test, y_test, classes, filename, title):
    """Plot t-SNE visualization"""
    try:
        # Create feature extractor model (ambil layer sebelum output)
        feature_layer = model.layers[-3]  # Layer sebelum output
        feature_extractor = keras.Model(
            inputs=model.input,
            outputs=feature_layer.output
        )
        
        # Extract features
        features = feature_extractor.predict(X_test, verbose=0)
        
        # Apply t-SNE
        tsne = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=1000)
        features_2d = tsne.fit_transform(features)
        
        plt.figure(figsize=(12, 10))
        scatter = plt.scatter(features_2d[:, 0], features_2d[:, 1], 
                             c=y_test, cmap='tab10', s=50, alpha=0.7)
        
        plt.title(f'{title} - t-SNE Visualization', fontsize=16, fontweight='bold', pad=20)
        plt.xlabel('t-SNE Component 1', fontsize=12, fontweight='bold')
        plt.ylabel('t-SNE Component 2', fontsize=12, fontweight='bold')
        
        # Create legend
        handles, labels = scatter.legend_elements()
        plt.legend(handles, classes, title="Classes", 
                  loc="upper right", fontsize=10, title_fontsize=12)
        
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.savefig(filename, dpi=300, bbox_inches='tight')
        plt.close()
    except Exception as e:
        print(f"t-SNE plot error: {e}")

# %%
def plot_attention_maps_complete(model, X_test, y_test, classes, filename):
    """Plot attention maps"""
    try:
        # Find attention layer
        attention_layer = None
        for layer in model.layers:
            if 'attention' in layer.name.lower():
                attention_layer = layer
                break
        
        if attention_layer:
            # Create model to get attention weights
            attention_model = keras.Model(
                inputs=model.input,
                outputs=attention_layer.output
            )
            
            # Get sample data
            sample_idx = np.random.choice(len(X_test), min(5, len(X_test)), replace=False)
            X_sample = X_test[sample_idx]
            
            # Get attention weights
            attention_weights = attention_model.predict(X_sample, verbose=0)
            
            fig, axes = plt.subplots(len(X_sample), 1, figsize=(12, 3*len(X_sample)))
            if len(X_sample) == 1:
                axes = [axes]
            
            for i, (ax, x, weights) in enumerate(zip(axes, X_sample, attention_weights)):
                # Plot ECG signal (gunakan lead pertama)
                time_axis = np.arange(len(x))
                ax.plot(time_axis, x[:, 0], 'b-', alpha=0.7, label='ECG Signal')
                
                # Overlay attention weights (normalized)
                weights_norm = (weights - weights.min()) / (weights.max() - weights.min() + 1e-8)
                ax.fill_between(time_axis, x[:, 0].min(), x[:, 0].max(), 
                               where=weights_norm > 0.5, alpha=0.3, color='red',
                               label='High Attention')
                
                ax.set_title(f'Sample {i+1} - Class: {classes[y_test[sample_idx[i]]]}', 
                           fontsize=10, fontweight='bold')
                ax.set_xlabel('Time Steps')
                ax.set_ylabel('Amplitude')
                ax.legend(fontsize=8)
                ax.grid(True, alpha=0.3)
            
            plt.tight_layout()
            plt.savefig(filename, dpi=300, bbox_inches='tight')
            plt.close()
    except Exception as e:
        print(f"Attention map plot error: {e}")

def plot_fold_comparison(folds_results, filename):
    """Plot perbandingan performance antar fold"""
    folds = [r['Fold'] for r in folds_results]
    accuracies = [r['Accuracy'] for r in folds_results]
    f1_scores = [r['F1_Score'] for r in folds_results]
    
    x = np.arange(len(folds))
    width = 0.35
    
    plt.figure(figsize=(12, 6))
    plt.bar(x - width/2, accuracies, width, label='Accuracy', alpha=0.8, color='skyblue')
    plt.bar(x + width/2, f1_scores, width, label='F1-Score', alpha=0.8, color='lightcoral')
    
    plt.xlabel('Fold', fontsize=14, fontweight='bold')
    plt.ylabel('Score', fontsize=14, fontweight='bold')
    plt.title('Cross-Validation Performance Comparison', fontsize=16, fontweight='bold', pad=20)
    plt.xticks(x, [f'Fold {f}' for f in folds])
    plt.ylim([0, 1])
    plt.legend(fontsize=12)
    plt.grid(True, alpha=0.3, axis='y')
    
    # Add value labels
    for i, (acc, f1) in enumerate(zip(accuracies, f1_scores)):
        plt.text(i - width/2, acc + 0.02, f'{acc:.3f}', ha='center', fontsize=10, fontweight='bold')
        plt.text(i + width/2, f1 + 0.02, f'{f1:.3f}', ha='center', fontsize=10, fontweight='bold')
    
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()

# %%
def plot_consistency(accuracies, filename):
    """Plot konsistensi akurasi antar fold"""
    plt.figure(figsize=(10, 6))
    
    # Plot line with markers
    plt.plot(range(1, len(accuracies) + 1), accuracies, 'o-', linewidth=3, markersize=10, 
             color='darkblue', markerfacecolor='red', markeredgewidth=2)
    
    # Plot mean line
    mean_acc = np.mean(accuracies)
    plt.axhline(y=mean_acc, color='green', linestyle='--', linewidth=2, 
                label=f'Mean: {mean_acc:.4f}')
    
    # Plot std range
    std_acc = np.std(accuracies)
    plt.fill_between(range(0, len(accuracies) + 2), 
                     mean_acc - std_acc, mean_acc + std_acc, 
                     alpha=0.2, color='green', label=f'±1 STD: {std_acc:.4f}')
    
    plt.xlabel('Fold', fontsize=14, fontweight='bold')
    plt.ylabel('Accuracy', fontsize=14, fontweight='bold')
    plt.title('Accuracy Consistency Across Folds', fontsize=16, fontweight='bold', pad=20)
    plt.xticks(range(1, len(accuracies) + 1))
    plt.ylim([0, 1])
    plt.legend(fontsize=12)
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()

def save_tabel3_efficiency(model, train_times, filename):
    """Save Tabel 3 - Model Efficiency"""
    # Count trainable parameters
    trainable_params = np.sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])
    
    # Calculate average time per epoch (estimate)
    avg_epoch_time = np.mean(train_times) / EPOCHS if EPOCHS > 0 else 0
    
    df = pd.DataFrame({
        'Metric': ['Trainable Parameters', 'Average Training Time per Fold (hours)', 
                   'Average Time per Epoch (seconds)', 'Total Training Time (hours)'],
        'Value': [trainable_params, 
                  f'{np.mean(train_times)/3600:.4f}',
                  f'{avg_epoch_time:.2f}',
                  f'{np.sum(train_times)/3600:.4f}']
    })
    df.to_csv(filename, index=False)

def save_tabel4_consistency(accuracies, filename):
    """Save Tabel 4 - Consistency Analysis"""
    mean_acc = np.mean(accuracies)
    std_acc = np.std(accuracies)
    cv = (std_acc / mean_acc) * 100 if mean_acc > 0 else 0
    
    df = pd.DataFrame({
        'Statistic': ['Mean Accuracy', 'Standard Deviation', 'Coefficient of Variation (%)',
                      'Min Accuracy', 'Max Accuracy', 'Range'],
        'Value': [f'{mean_acc:.4f}', f'{std_acc:.4f}', f'{cv:.2f}',
                  f'{np.min(accuracies):.4f}', f'{np.max(accuracies):.4f}',
                  f'{np.max(accuracies) - np.min(accuracies):.4f}']
    })
    df.to_csv(filename, index=False)

# %%
# ====================== GAN FUNCTIONS ======================
def normalize_for_gan(X_class):
    """Normalize untuk GAN: [-1, 1] range"""
    X_norm = X_class.copy()
    for i in range(len(X_norm)):
        sample = X_norm[i]
        min_val = np.min(sample)
        max_val = np.max(sample)
        if max_val - min_val > 0:
            X_norm[i] = (sample - min_val) / (max_val - min_val)
        else:
            X_norm[i] = sample
    X_norm = X_norm * 2 - 1
    return X_norm

def denormalize_from_gan(X_gan):
    """Convert kembali dari [-1, 1] ke original scale"""
    X_denorm = (X_gan + 1) / 2
    return X_denorm

def build_generator(latent_dim, output_dim):
    """Generator untuk ECG 1D"""
    model = keras.Sequential([
        layers.Dense(256, input_dim=latent_dim),
        layers.LeakyReLU(alpha=0.2),
        layers.BatchNormalization(),
        
        layers.Dense(512),
        layers.LeakyReLU(alpha=0.2),
        layers.BatchNormalization(),
        
        layers.Dense(1024),
        layers.LeakyReLU(alpha=0.2),
        layers.BatchNormalization(),
        
        layers.Dense(output_dim),
        layers.Activation('tanh')
    ])
    return model

def build_discriminator(input_dim):
    """Discriminator untuk ECG 1D"""
    model = keras.Sequential([
        layers.Dense(512, input_dim=input_dim),
        layers.LeakyReLU(alpha=0.2),
        layers.Dropout(0.3),
        
        layers.Dense(256),
        layers.LeakyReLU(alpha=0.2),
        layers.Dropout(0.3),
        
        layers.Dense(128),
        layers.LeakyReLU(alpha=0.2),
        layers.Dropout(0.3),
        
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(loss='binary_crossentropy',
                  optimizer=Adam(learning_rate=0.0002, beta_1=0.5),
                  metrics=['accuracy'])
    return model

# %%
def build_gan(generator, discriminator):
    """GAN Model"""
    discriminator.trainable = False
    model = keras.Sequential([
        generator,
        discriminator
    ])
    model.compile(loss='binary_crossentropy',
                  optimizer=Adam(learning_rate=0.0002, beta_1=0.5))
    return model

def train_gan_per_class(X_class_original, n_samples_needed):
    """
    Train GAN untuk satu kelas spesifik
    """
    original_shape = X_class_original.shape
    X_class_flat = X_class_original.reshape(len(X_class_original), -1)
    X_class_norm = normalize_for_gan(X_class_flat)
    
    generator = build_generator(LATENT_DIM, X_class_norm.shape[1])
    discriminator = build_discriminator(X_class_norm.shape[1])
    gan = build_gan(generator, discriminator)
    
    batch_size = min(GAN_BATCH, len(X_class_norm))
    half_batch = batch_size // 2
    
    for epoch in range(GAN_EPOCHS):
        # Train Discriminator
        idx = np.random.randint(0, len(X_class_norm), half_batch)
        real_samples = X_class_norm[idx]
        real_labels = np.ones((half_batch, 1))
        
        noise = np.random.normal(0, 1, (half_batch, LATENT_DIM))
        fake_samples = generator.predict(noise, verbose=0)
        fake_labels = np.zeros((half_batch, 1))
        
        d_loss_real = discriminator.train_on_batch(real_samples, real_labels)
        d_loss_fake = discriminator.train_on_batch(fake_samples, fake_labels)
        
        # Train Generator
        noise = np.random.normal(0, 1, (batch_size, LATENT_DIM))
        valid_labels = np.ones((batch_size, 1))
        g_loss = gan.train_on_batch(noise, valid_labels)
        
        if (epoch + 1) % 100 == 0:
            print(f"  GAN Epoch {epoch+1}/{GAN_EPOCHS} - D Loss: {0.5*np.add(d_loss_real[0], d_loss_fake[0]):.4f}, G Loss: {g_loss:.4f}")
    
    # Generate samples
    n_to_generate = n_samples_needed
    noise = np.random.normal(0, 1, (n_to_generate, LATENT_DIM))
    generated_flat = generator.predict(noise, verbose=0)
    generated_denorm = denormalize_from_gan(generated_flat)
    generated_samples = generated_denorm.reshape(-1, *original_shape[1:])
    
    return generated_samples

def balance_with_gan(X_train, y_train):
    """
    Balance dataset menggunakan GAN per kelas minoritas
    """
    print("\n=== Balancing dengan GAN ===")
    class_counts = Counter(y_train)
    max_count = max(class_counts.values())
    
    X_balanced = [X_train]
    y_balanced = [y_train]
    
    for class_id in np.unique(y_train):
        count = class_counts[class_id]
        needed = max_count - count
        
        if needed > 0:
            print(f"  Kelas {class_id}: {count} samples -> perlu {needed} samples baru")
            
            X_class = X_train[y_train == class_id]
            
            if len(X_class) < 10:
                print(f"  ⚠️  Kelas {class_id} terlalu sedikit ({len(X_class)} samples), gunakan oversampling sederhana")
                indices = np.random.choice(len(X_class), needed, replace=True)
                synthetic = X_class[indices] + np.random.normal(0, 0.01, X_class[indices].shape)
            else:
                print(f"  🏗️  Training GAN untuk kelas {class_id}...")
                synthetic = train_gan_per_class(X_class, needed)
                print(f"  ✅ Generated {len(synthetic)} samples untuk kelas {class_id}")
            
            X_balanced.append(synthetic)
            y_balanced.append(np.full(len(synthetic), class_id))
    
    X_balanced = np.vstack(X_balanced)
    y_balanced = np.concatenate(y_balanced)
    
    idx = np.random.permutation(len(X_balanced))
    X_balanced = X_balanced[idx]
    y_balanced = y_balanced[idx]
    
    print(f"  Dataset setelah balancing: {X_balanced.shape}")
    print(f"  Distribusi kelas: {dict(Counter(y_balanced))}")
    
    return X_balanced, y_balanced

# %%
# ====================== CNN-RNN MODEL ======================
def build_model(input_shape, num_classes):
    """Model CNN-RNN dengan Attention"""
    inputs = layers.Input(shape=input_shape)
    
    # CNN Block 1
    x = layers.Conv1D(64, 7, padding='same', activation='relu')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Dropout(DROPOUT)(x)
    
    # CNN Block 2
    x = layers.Conv1D(128, 5, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Dropout(DROPOUT)(x)
    
    # CNN Block 3
    x = layers.Conv1D(256, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Dropout(DROPOUT)(x)
    
    # RNN Block dengan SimpleRNN (bukan LSTM)
    x = layers.SimpleRNN(RNN_UNITS, return_sequences=True, activation='tanh')(x)
    x = layers.Dropout(DROPOUT)(x)
    x = layers.SimpleRNN(RNN_UNITS // 2, return_sequences=True, activation='tanh')(x)
    x = layers.Dropout(DROPOUT)(x)
    
    # Attention Layer
    x = AttentionLayer()(x)
    
    # Dense Layers
    x = layers.Dense(128, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(DROPOUT_DENSE)(x)
    
    x = layers.Dense(64, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(DROPOUT_DENSE)(x)
    
    # Output Layer
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    
    model = models.Model(inputs, outputs)
    model.compile(optimizer=Adam(LR),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
# ====================== MAIN FUNCTION ======================
def main():
    start_total = time.time()
    MODEL_NAME = "CNN_RNN_GAN"
    
    # Load data
    print("Loading preprocessed data...")
    X = np.load('X_preprocessed.npy')
    y = np.load('y_preprocessed.npy')
    le = joblib.load('label_encoder_location.joblib')
    
    print(f"Data shape: {X.shape}")
    print(f"Label shape: {y.shape}")
    print(f"Classes: {le.classes_}")
    print(f"Class distribution: {dict(Counter(y))}")
    
    # Cross-validation
    skf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=42)
    results = []
    best_model = None
    best_accuracy = 0
    best_fold_idx = 0
    best_history = None
    fold_data = []  # Simpan data tiap fold
    
    for fold, (train_idx, test_idx) in enumerate(skf.split(X, y), 1):
        fold_start = time.time()
        print(f"\n{'='*60}")
        print(f"FOLD {fold}/{FOLDS}")
        print(f"{'='*60}")
        
        # Split data
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]
        
        print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")
        print(f"Train distribution: {dict(Counter(y_train))}")
        
        # Balance dengan GAN
        X_train_bal, y_train_bal = balance_with_gan(X_train, y_train)
        
        # Build dan train model
        model = build_model(X.shape[1:], len(le.classes_))
        
        callbacks = [
            EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True, verbose=0),
            ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=0)
        ]
        
        print("\nTraining CNN-RNN model...")
        history = model.fit(
            X_train_bal, y_train_bal,
            validation_split=0.2,
            epochs=EPOCHS,
            batch_size=BATCH,
            callbacks=callbacks,
            verbose=1
        )
        
        # Evaluate
        y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='weighted')
        fold_time = time.time() - fold_start
        
        print(f"Fold {fold} Results:")
        print(f"  Accuracy:  {acc:.4f}")
        print(f"  F1-Score:  {f1:.4f}")
        print(f"  Time:      {fold_time/60:.2f} minutes")
        
        fold_result = {
            'Fold': fold,
            'Accuracy': acc,
            'F1_Score': f1,
            'Train_Time': fold_time
        }
        results.append(fold_result)
        
        # Simpan data fold
        fold_data.append({
            'X_test': X_test,
            'y_test': y_test,
            'history': history
        })
        
        # Update best model
        if acc > best_accuracy:
            best_accuracy = acc
            best_model = model
            best_fold_idx = fold - 1
            best_history = history
            print(f"  🏆 New best model! Accuracy: {acc:.4f}")
    
    # ====================== OUTPUT LENGKAP ======================
    print(f"\n{'='*60}")
    print("GENERATING 13 OUTPUT FILES...")
    print(f"{'='*60}")
    
    # Retrieve test data from the fold that produced best model
    best_fold_data = fold_data[best_fold_idx]
    best_X_test = best_fold_data['X_test']
    best_y_test = best_fold_data['y_test']
    
    y_pred_probs = best_model.predict(best_X_test, verbose=0)
    y_pred = np.argmax(y_pred_probs, axis=1)
    
    # 1. Confusion Matrix
    plot_confusion_matrix_complete(best_y_test, y_pred, le.classes_, 
                                  f'FINAL_CM_{MODEL_NAME}.png', f'{MODEL_NAME} CM')
    print("✓ 1. Confusion Matrix saved")
    
    # 2. ROC Curve
    plot_roc_curve_complete(best_y_test, y_pred_probs, le.classes_, 
                           f'FINAL_ROC_{MODEL_NAME}.png', f'{MODEL_NAME} ROC')
    print("✓ 2. ROC Curve saved")
    
    # 3. Learning Curve
    plot_learning_curve_complete(best_history, f'FINAL_Learning_Curve_{MODEL_NAME}.png')
    print("✓ 3. Learning Curve saved")
    
    # 4. t-SNE Visualization
    plot_tsne_complete(best_model, best_X_test, best_y_test, le.classes_, 
                      f'FINAL_TSNE_{MODEL_NAME}.png', f'{MODEL_NAME}')
    print("✓ 4. t-SNE saved")
    
    # 5. Attention Maps
    plot_attention_maps_complete(best_model, best_X_test, best_y_test, le.classes_, 
                                f'FINAL_Attention_{MODEL_NAME}.png')
    print("✓ 5. Attention Maps saved")
    
    # 6. Fold Comparison
    plot_fold_comparison(results, f'FINAL_Fold_Comparison_{MODEL_NAME}.png')
    print("✓ 6. Fold Comparison saved")
    
    # 7. Consistency Plot
    accs = [r['Accuracy'] for r in results]
    plot_consistency(accs, f'FINAL_Consistency_{MODEL_NAME}.png')
    print("✓ 7. Consistency Plot saved")
    
    # 8. Save Best Model
    best_model.save(f'FINAL_best_model_{MODEL_NAME}.h5')
    print("✓ 8. Best Model saved")
    
    # 9. CV Results CSV
    pd.DataFrame(results).to_csv(f'FINAL_CV_{MODEL_NAME}.csv', index=False)
    print("✓ 9. CV Results CSV saved")
    
    # 10. Tabel 1 - Summary Metrics
    df_t1 = pd.DataFrame({
        'Metric': ['Mean Accuracy', 'Best Accuracy', 'Mean F1'],
        'Value': [np.mean(accs), best_accuracy, np.mean([r['F1_Score'] for r in results])]
    })
    df_t1.to_csv(f'FINAL_Tabel1_{MODEL_NAME}.csv', index=False)
    print("✓ 10. Tabel 1 saved")
    
    # 11. Tabel 2 - Per Class Metrics
    prec, rec, f1_s, supp = precision_recall_fscore_support(best_y_test, y_pred, 
                                                           average=None, zero_division=0)
    per_class_acc = []
    for c in range(len(le.classes_)):
        mask = (best_y_test == c)
        if np.sum(mask) > 0: 
            per_class_acc.append(accuracy_score(best_y_test[mask], y_pred[mask]))
        else: 
            per_class_acc.append(0.0)
    
    df_t2 = pd.DataFrame({
        'Kelas': le.classes_,
        'Akurasi': per_class_acc,
        'Recall': rec,
        'Precision': prec,
        'F1-Score': f1_s,
        'Support': supp
    })
    df_t2.to_csv(f'FINAL_Tabel2_{MODEL_NAME}.csv', index=False)
    print("✓ 11. Tabel 2 saved")
    
    # 12. Tabel 3 - Efficiency
    times = [r['Train_Time'] for r in results]
    save_tabel3_efficiency(best_model, times, f'FINAL_Tabel3_{MODEL_NAME}.csv')
    print("✓ 12. Tabel 3 saved")
    
    # 13. Tabel 4 - Consistency
    save_tabel4_consistency(accs, f'FINAL_Tabel4_{MODEL_NAME}.csv')
    print("✓ 13. Tabel 4 saved")
    
    print(f"\n{'='*60}")
    print(f"ALL 13 OUTPUTS COMPLETED FOR {MODEL_NAME}!")
    print(f"{'='*60}")
    print(f"Model: CNN-RNN with Attention and GAN")
    print(f"Best Accuracy: {best_accuracy:.4f} (Fold {best_fold_idx + 1})")
    print(f"Mean Accuracy: {np.mean(accs):.4f} ± {np.std(accs):.4f}")
    print(f"Mean F1-Score: {np.mean([r['F1_Score'] for r in results]):.4f}")
    print(f"Total Time: {(time.time() - start_total)/3600:.2f} hours")
    
    print(f"\n📁 13 Output Files Generated:")
    print("  1. FINAL_CM_CNN_RNN_GAN.png           - Confusion Matrix")
    print("  2. FINAL_ROC_CNN_RNN_GAN.png          - ROC Curve")
    print("  3. FINAL_Learning_Curve_CNN_RNN_GAN.png - Learning Curve")
    print("  4. FINAL_TSNE_CNN_RNN_GAN.png         - t-SNE Visualization")
    print("  5. FINAL_Attention_CNN_RNN_GAN.png    - Attention Maps")
    print("  6. FINAL_Fold_Comparison_CNN_RNN_GAN.png - Fold Comparison")
    print("  7. FINAL_Consistency_CNN_RNN_GAN.png  - Consistency Plot")
    print("  8. FINAL_best_model_CNN_RNN_GAN.h5    - Best Model")
    print("  9. FINAL_CV_CNN_RNN_GAN.csv           - CV Results")
    print(" 10. FINAL_Tabel1_CNN_RNN_GAN.csv       - Summary Metrics")
    print(" 11. FINAL_Tabel2_CNN_RNN_GAN.csv       - Per Class Metrics")
    print(" 12. FINAL_Tabel3_CNN_RNN_GAN.csv       - Efficiency Analysis")
    print(" 13. FINAL_Tabel4_CNN_RNN_GAN.csv       - Consistency Analysis")
    print(f"\n✅ CNN-RNN with GAN Implementation COMPLETE!")

if __name__ == "__main__":
    main()
# Out:
# Loading preprocessed data...
# Data shape: (5256, 1000, 12)
# Label shape: (5256,)
# Classes: ['Left_Ventricular_Region' 'Outflow_Tract_Region'
#  'Right_Ventricular_Region' 'Septal_Region']
# Class distribution: {np.int64(2): 2646, np.int64(3): 1204, np.int64(0): 1196, np.int64(1): 210}
#
# ============================================================
# FOLD 1/5
# ============================================================
# Train shape: (4204, 1000, 12), Test shape: (1052, 1000, 12)
# Train distribution: {np.int64(2): 2116, np.int64(3): 964, np.int64(0): 956, np.int64(1): 168}
#
# === Balancing dengan GAN ===
#   Kelas 0: 956 samples -> perlu 1160 samples baru
#   🏗️  Training GAN untuk kelas 0...
# I0000 00:00:1769964400.342661      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1769964400.348321      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1769964402.154510     123 service.cc:152] XLA service 0x797454005680 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1769964402.154541     123 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1769964402.154545     123 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1769964402.258208     123 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1769964402.842166     123 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   GAN Epoch 100/500 - D Loss: 1.0054, G Loss: 0.1581
#   GAN Epoch 200/500 - D Loss: 1.6145, G Loss: 0.0885
#   GAN Epoch 300/500 - D Loss: 2.2614, G Loss: 0.0619
#   GAN Epoch 400/500 - D Loss: 2.8153, G Loss: 0.0479
#   GAN Epoch 500/500 - D Loss: 3.2234, G Loss: 0.0390
#   ✅ Generated 1160 samples untuk kelas 0
#   Kelas 1: 168 samples -> perlu 1948 samples baru
#   🏗️  Training GAN untuk kelas 1...
#   GAN Epoch 100/500 - D Loss: 1.0880, G Loss: 0.1266
#   GAN Epoch 200/500 - D Loss: 1.7322, G Loss: 0.0693
#   GAN Epoch 300/500 - D Loss: 2.3699, G Loss: 0.0484
#   GAN Epoch 400/500 - D Loss: 2.9347, G Loss: 0.0373
#   GAN Epoch 500/500 - D Loss: 3.3789, G Loss: 0.0304
#   ✅ Generated 1948 samples untuk kelas 1
#   Kelas 3: 964 samples -> perlu 1152 samples baru
#   🏗️  Training GAN untuk kelas 3...
#   GAN Epoch 100/500 - D Loss: 1.0738, G Loss: 0.1412
#   GAN Epoch 200/500 - D Loss: 1.7168, G Loss: 0.0782
#   GAN Epoch 300/500 - D Loss: 2.3540, G Loss: 0.0545
#   GAN Epoch 400/500 - D Loss: 2.8948, G Loss: 0.0419
#   GAN Epoch 500/500 - D Loss: 3.3361, G Loss: 0.0341
#   ✅ Generated 1152 samples untuk kelas 3
#   Dataset setelah balancing: (8464, 1000, 12)
#   Distribusi kelas: {np.int64(2): 2116, np.int64(1): 2116, np.int64(0): 2116, np.int64(3): 2116}
#
# Training CNN-RNN model...
# Epoch 1/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 32s 83ms/step - accuracy: 0.3895 - loss: 1.7338 - val_accuracy: 0.4849 - val_loss: 1.1330 - learning_rate: 0.0010
# Epoch 2/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.4434 - loss: 1.2952 - val_accuracy: 0.5186 - val_loss: 1.1293 - learning_rate: 0.0010
# Epoch 3/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.4533 - loss: 1.1825 - val_accuracy: 0.5275 - val_loss: 1.0526 - learning_rate: 0.0010
# Epoch 4/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.4820 - loss: 1.0878 - val_accuracy: 0.5446 - val_loss: 1.0043 - learning_rate: 0.0010
# Epoch 5/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5139 - loss: 1.0465 - val_accuracy: 0.5600 - val_loss: 0.9907 - learning_rate: 0.0010
# Epoch 6/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5190 - loss: 1.0279 - val_accuracy: 0.5564 - val_loss: 0.9767 - learning_rate: 0.0010
# Epoch 7/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5238 - loss: 1.0198 - val_accuracy: 0.5558 - val_loss: 0.9811 - learning_rate: 0.0010
# Epoch 8/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5260 - loss: 0.9964 - val_accuracy: 0.5546 - val_loss: 0.9655 - learning_rate: 0.0010
# Epoch 9/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5503 - loss: 0.9798 - val_accuracy: 0.5505 - val_loss: 0.9552 - learning_rate: 0.0010
# Epoch 10/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5464 - loss: 0.9857 - val_accuracy: 0.5582 - val_loss: 0.9884 - learning_rate: 0.0010
# Epoch 11/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5624 - loss: 0.9642 - val_accuracy: 0.5558 - val_loss: 0.9764 - learning_rate: 0.0010
# Epoch 12/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5550 - loss: 0.9626 - val_accuracy: 0.5694 - val_loss: 1.0134 - learning_rate: 0.0010
# Epoch 13/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5932 - loss: 0.9180 - val_accuracy: 0.4353 - val_loss: 1.4577 - learning_rate: 0.0010
# Epoch 14/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6286 - loss: 0.8462 - val_accuracy: 0.5605 - val_loss: 2.2239 - learning_rate: 0.0010
# Epoch 15/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6767 - loss: 0.7708 - val_accuracy: 0.5670 - val_loss: 1.6162 - learning_rate: 5.0000e-04
# Epoch 16/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7021 - loss: 0.7041 - val_accuracy: 0.5877 - val_loss: 2.0490 - learning_rate: 5.0000e-04
# Epoch 17/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7095 - loss: 0.6761 - val_accuracy: 0.5812 - val_loss: 3.5514 - learning_rate: 5.0000e-04
# Epoch 18/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7224 - loss: 0.6563 - val_accuracy: 0.4347 - val_loss: 3.4173 - learning_rate: 5.0000e-04
# Epoch 19/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7354 - loss: 0.6224 - val_accuracy: 0.5889 - val_loss: 0.8316 - learning_rate: 5.0000e-04
# Epoch 20/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7372 - loss: 0.6295 - val_accuracy: 0.5889 - val_loss: 4.8813 - learning_rate: 5.0000e-04
# Epoch 21/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7536 - loss: 0.6139 - val_accuracy: 0.4613 - val_loss: 5.1420 - learning_rate: 5.0000e-04
# Epoch 22/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7727 - loss: 0.5789 - val_accuracy: 0.4660 - val_loss: 5.0226 - learning_rate: 5.0000e-04
# Epoch 23/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7681 - loss: 0.5727 - val_accuracy: 0.7998 - val_loss: 0.5184 - learning_rate: 5.0000e-04
# Epoch 24/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7757 - loss: 0.5519 - val_accuracy: 0.6131 - val_loss: 5.6567 - learning_rate: 5.0000e-04
# Epoch 25/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7849 - loss: 0.5334 - val_accuracy: 0.4873 - val_loss: 3.2637 - learning_rate: 5.0000e-04
# Epoch 26/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7989 - loss: 0.5211 - val_accuracy: 0.6143 - val_loss: 5.1225 - learning_rate: 5.0000e-04
# Epoch 27/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8143 - loss: 0.4852 - val_accuracy: 0.6054 - val_loss: 4.5488 - learning_rate: 5.0000e-04
# Epoch 28/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8032 - loss: 0.5173 - val_accuracy: 0.5062 - val_loss: 2.0437 - learning_rate: 5.0000e-04
# Epoch 29/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8192 - loss: 0.4620 - val_accuracy: 0.5056 - val_loss: 3.1036 - learning_rate: 2.5000e-04
# Epoch 30/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8369 - loss: 0.4392 - val_accuracy: 0.6539 - val_loss: 1.1755 - learning_rate: 2.5000e-04
# Epoch 31/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8478 - loss: 0.4085 - val_accuracy: 0.5032 - val_loss: 5.4329 - learning_rate: 2.5000e-04
# Epoch 32/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8462 - loss: 0.4178 - val_accuracy: 0.7815 - val_loss: 0.5638 - learning_rate: 2.5000e-04
# Epoch 33/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8558 - loss: 0.3969 - val_accuracy: 0.5139 - val_loss: 4.1752 - learning_rate: 2.5000e-04
# Epoch 34/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8591 - loss: 0.3803 - val_accuracy: 0.6816 - val_loss: 1.8979 - learning_rate: 1.2500e-04
# Epoch 35/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8743 - loss: 0.3521 - val_accuracy: 0.8606 - val_loss: 0.3744 - learning_rate: 1.2500e-04
# Epoch 36/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8701 - loss: 0.3505 - val_accuracy: 0.7460 - val_loss: 0.8914 - learning_rate: 1.2500e-04
# Epoch 37/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8729 - loss: 0.3414 - val_accuracy: 0.7578 - val_loss: 0.7393 - learning_rate: 1.2500e-04
# Epoch 38/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8649 - loss: 0.3494 - val_accuracy: 0.7466 - val_loss: 0.9075 - learning_rate: 1.2500e-04
# Epoch 39/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8878 - loss: 0.3185 - val_accuracy: 0.6970 - val_loss: 1.8979 - learning_rate: 1.2500e-04
# Epoch 40/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8793 - loss: 0.3169 - val_accuracy: 0.8169 - val_loss: 0.5382 - learning_rate: 1.2500e-04
# Epoch 41/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8911 - loss: 0.3043 - val_accuracy: 0.8553 - val_loss: 0.4056 - learning_rate: 6.2500e-05
# Epoch 42/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8910 - loss: 0.2935 - val_accuracy: 0.6621 - val_loss: 3.6278 - learning_rate: 6.2500e-05
# Epoch 43/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8864 - loss: 0.3022 - val_accuracy: 0.8004 - val_loss: 0.5659 - learning_rate: 6.2500e-05
# Epoch 44/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8915 - loss: 0.2941 - val_accuracy: 0.8736 - val_loss: 0.3862 - learning_rate: 6.2500e-05
# Epoch 45/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8975 - loss: 0.2818 - val_accuracy: 0.7549 - val_loss: 0.8577 - learning_rate: 6.2500e-05
# Epoch 46/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8919 - loss: 0.2848 - val_accuracy: 0.6787 - val_loss: 2.3174 - learning_rate: 3.1250e-05
# Epoch 47/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8983 - loss: 0.2840 - val_accuracy: 0.8015 - val_loss: 0.5889 - learning_rate: 3.1250e-05
# Epoch 48/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9015 - loss: 0.2746 - val_accuracy: 0.8311 - val_loss: 0.4920 - learning_rate: 3.1250e-05
# Epoch 49/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9036 - loss: 0.2709 - val_accuracy: 0.7307 - val_loss: 1.1221 - learning_rate: 3.1250e-05
# Epoch 50/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9060 - loss: 0.2706 - val_accuracy: 0.7177 - val_loss: 1.4411 - learning_rate: 3.1250e-05
# Fold 1 Results:
#   Accuracy:  0.8156
#   F1-Score:  0.8031
#   Time:      8.68 minutes
#   🏆 New best model! Accuracy: 0.8156
#
# ============================================================
# FOLD 2/5
# ============================================================
# Train shape: (4205, 1000, 12), Test shape: (1051, 1000, 12)
# Train distribution: {np.int64(2): 2117, np.int64(3): 963, np.int64(0): 957, np.int64(1): 168}
#
# === Balancing dengan GAN ===
#   Kelas 0: 957 samples -> perlu 1160 samples baru
#   🏗️  Training GAN untuk kelas 0...
#   GAN Epoch 100/500 - D Loss: 1.0789, G Loss: 0.0700
#   GAN Epoch 200/500 - D Loss: 1.7567, G Loss: 0.0384
#   GAN Epoch 300/500 - D Loss: 2.4051, G Loss: 0.0266
#   GAN Epoch 400/500 - D Loss: 2.9453, G Loss: 0.0204
#   GAN Epoch 500/500 - D Loss: 3.3675, G Loss: 0.0165
#   ✅ Generated 1160 samples untuk kelas 0
#   Kelas 1: 168 samples -> perlu 1949 samples baru
#   🏗️  Training GAN untuk kelas 1...
#   GAN Epoch 100/500 - D Loss: 1.0802, G Loss: 0.1286
#   GAN Epoch 200/500 - D Loss: 1.7348, G Loss: 0.0712
#   GAN Epoch 300/500 - D Loss: 2.3594, G Loss: 0.0495
#   GAN Epoch 400/500 - D Loss: 2.8849, G Loss: 0.0379
#   GAN Epoch 500/500 - D Loss: 3.3103, G Loss: 0.0308
#   ✅ Generated 1949 samples untuk kelas 1
#   Kelas 3: 963 samples -> perlu 1154 samples baru
#   🏗️  Training GAN untuk kelas 3...
#   GAN Epoch 100/500 - D Loss: 1.0686, G Loss: 0.1699
#   GAN Epoch 200/500 - D Loss: 1.6369, G Loss: 0.0954
#   GAN Epoch 300/500 - D Loss: 2.2446, G Loss: 0.0663
#   GAN Epoch 400/500 - D Loss: 2.7450, G Loss: 0.0511
#   GAN Epoch 500/500 - D Loss: 3.1560, G Loss: 0.0417
#   ✅ Generated 1154 samples untuk kelas 3
#   Dataset setelah balancing: (8468, 1000, 12)
#   Distribusi kelas: {np.int64(0): 2117, np.int64(3): 2117, np.int64(2): 2117, np.int64(1): 2117}
#
# Training CNN-RNN model...
# Epoch 1/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 31s 83ms/step - accuracy: 0.3719 - loss: 1.7869 - val_accuracy: 0.5071 - val_loss: 1.1138 - learning_rate: 0.0010
# Epoch 2/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.4275 - loss: 1.3371 - val_accuracy: 0.5224 - val_loss: 1.0718 - learning_rate: 0.0010
# Epoch 3/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.4716 - loss: 1.1458 - val_accuracy: 0.5348 - val_loss: 1.0643 - learning_rate: 0.0010
# Epoch 4/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.4905 - loss: 1.0762 - val_accuracy: 0.4705 - val_loss: 1.0743 - learning_rate: 0.0010
# Epoch 5/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.5023 - loss: 1.0389 - val_accuracy: 0.5401 - val_loss: 1.0235 - learning_rate: 0.0010
# Epoch 6/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5194 - loss: 1.0264 - val_accuracy: 0.5407 - val_loss: 1.0244 - learning_rate: 0.0010
# Epoch 7/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5243 - loss: 1.0001 - val_accuracy: 0.5360 - val_loss: 1.0678 - learning_rate: 0.0010
# Epoch 8/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5340 - loss: 0.9889 - val_accuracy: 0.5472 - val_loss: 1.0031 - learning_rate: 0.0010
# Epoch 9/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5409 - loss: 0.9700 - val_accuracy: 0.4587 - val_loss: 0.9983 - learning_rate: 0.0010
# Epoch 10/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5366 - loss: 0.9659 - val_accuracy: 0.4445 - val_loss: 1.0319 - learning_rate: 0.0010
# Epoch 11/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5512 - loss: 0.9493 - val_accuracy: 0.5431 - val_loss: 1.2346 - learning_rate: 0.0010
# Epoch 12/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5592 - loss: 0.9543 - val_accuracy: 0.5372 - val_loss: 0.9881 - learning_rate: 0.0010
# Epoch 13/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5556 - loss: 0.9465 - val_accuracy: 0.4581 - val_loss: 1.3140 - learning_rate: 0.0010
# Epoch 14/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5917 - loss: 0.8964 - val_accuracy: 0.5472 - val_loss: 1.0316 - learning_rate: 0.0010
# Epoch 15/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6147 - loss: 0.8612 - val_accuracy: 0.5708 - val_loss: 1.1707 - learning_rate: 0.0010
# Epoch 16/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.6336 - loss: 0.8214 - val_accuracy: 0.5767 - val_loss: 1.3490 - learning_rate: 0.0010
# Epoch 17/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.6529 - loss: 0.7818 - val_accuracy: 0.4581 - val_loss: 2.4362 - learning_rate: 0.0010
# Epoch 18/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6917 - loss: 0.7116 - val_accuracy: 0.4652 - val_loss: 2.7863 - learning_rate: 5.0000e-04
# Epoch 19/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.7068 - loss: 0.6770 - val_accuracy: 0.6930 - val_loss: 0.6875 - learning_rate: 5.0000e-04
# Epoch 20/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7201 - loss: 0.6561 - val_accuracy: 0.7462 - val_loss: 0.6006 - learning_rate: 5.0000e-04
# Epoch 21/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7313 - loss: 0.6359 - val_accuracy: 0.5832 - val_loss: 2.4930 - learning_rate: 5.0000e-04
# Epoch 22/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7379 - loss: 0.6173 - val_accuracy: 0.5006 - val_loss: 2.6446 - learning_rate: 5.0000e-04
# Epoch 23/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7480 - loss: 0.5992 - val_accuracy: 0.7645 - val_loss: 0.5504 - learning_rate: 5.0000e-04
# Epoch 24/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7639 - loss: 0.5814 - val_accuracy: 0.5195 - val_loss: 2.1596 - learning_rate: 5.0000e-04
# Epoch 25/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7646 - loss: 0.5619 - val_accuracy: 0.5224 - val_loss: 2.6042 - learning_rate: 5.0000e-04
# Epoch 26/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7681 - loss: 0.5577 - val_accuracy: 0.5313 - val_loss: 2.6855 - learning_rate: 5.0000e-04
# Epoch 27/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7870 - loss: 0.5256 - val_accuracy: 0.6665 - val_loss: 1.0411 - learning_rate: 5.0000e-04
# Epoch 28/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8084 - loss: 0.4934 - val_accuracy: 0.5224 - val_loss: 2.6917 - learning_rate: 5.0000e-04
# Epoch 29/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8134 - loss: 0.4735 - val_accuracy: 0.6865 - val_loss: 0.9131 - learning_rate: 2.5000e-04
# Epoch 30/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8288 - loss: 0.4365 - val_accuracy: 0.6612 - val_loss: 1.1125 - learning_rate: 2.5000e-04
# Epoch 31/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8349 - loss: 0.4230 - val_accuracy: 0.6405 - val_loss: 1.4205 - learning_rate: 2.5000e-04
# Epoch 32/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8325 - loss: 0.4281 - val_accuracy: 0.7426 - val_loss: 0.7544 - learning_rate: 2.5000e-04
# Epoch 33/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8375 - loss: 0.4055 - val_accuracy: 0.6139 - val_loss: 3.0766 - learning_rate: 2.5000e-04
# Epoch 34/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8498 - loss: 0.3805 - val_accuracy: 0.6328 - val_loss: 1.7740 - learning_rate: 1.2500e-04
# Epoch 35/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8655 - loss: 0.3511 - val_accuracy: 0.6257 - val_loss: 3.3125 - learning_rate: 1.2500e-04
# Epoch 36/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8663 - loss: 0.3521 - val_accuracy: 0.6411 - val_loss: 2.1818 - learning_rate: 1.2500e-04
# Epoch 37/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8698 - loss: 0.3310 - val_accuracy: 0.6311 - val_loss: 3.1857 - learning_rate: 1.2500e-04
# Epoch 38/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8684 - loss: 0.3467 - val_accuracy: 0.6494 - val_loss: 1.6055 - learning_rate: 1.2500e-04
# Fold 2 Results:
#   Accuracy:  0.7707
#   F1-Score:  0.7444
#   Time:      7.29 minutes
#
# ============================================================
# FOLD 3/5
# ============================================================
# Train shape: (4205, 1000, 12), Test shape: (1051, 1000, 12)
# Train distribution: {np.int64(2): 2117, np.int64(3): 963, np.int64(0): 957, np.int64(1): 168}
#
# === Balancing dengan GAN ===
#   Kelas 0: 957 samples -> perlu 1160 samples baru
#   🏗️  Training GAN untuk kelas 0...
#   GAN Epoch 100/500 - D Loss: 1.0965, G Loss: 0.0927
#   GAN Epoch 200/500 - D Loss: 1.7582, G Loss: 0.0507
#   GAN Epoch 300/500 - D Loss: 2.4239, G Loss: 0.0353
#   GAN Epoch 400/500 - D Loss: 2.9821, G Loss: 0.0271
#   GAN Epoch 500/500 - D Loss: 3.4084, G Loss: 0.0220
#   ✅ Generated 1160 samples untuk kelas 0
#   Kelas 1: 168 samples -> perlu 1949 samples baru
#   🏗️  Training GAN untuk kelas 1...
#   GAN Epoch 100/500 - D Loss: 1.1129, G Loss: 0.1845
#   GAN Epoch 200/500 - D Loss: 1.7059, G Loss: 0.1024
#   GAN Epoch 300/500 - D Loss: 2.3267, G Loss: 0.0711
#   GAN Epoch 400/500 - D Loss: 2.8394, G Loss: 0.0547
#   GAN Epoch 500/500 - D Loss: 3.2595, G Loss: 0.0446
#   ✅ Generated 1949 samples untuk kelas 1
#   Kelas 3: 963 samples -> perlu 1154 samples baru
#   🏗️  Training GAN untuk kelas 3...
#   GAN Epoch 100/500 - D Loss: 1.0813, G Loss: 0.1177
#   GAN Epoch 200/500 - D Loss: 1.7524, G Loss: 0.0652
#   GAN Epoch 300/500 - D Loss: 2.4518, G Loss: 0.0454
#   GAN Epoch 400/500 - D Loss: 2.9935, G Loss: 0.0348
#   GAN Epoch 500/500 - D Loss: 3.4487, G Loss: 0.0283
#   ✅ Generated 1154 samples untuk kelas 3
#   Dataset setelah balancing: (8468, 1000, 12)
#   Distribusi kelas: {np.int64(0): 2117, np.int64(1): 2117, np.int64(3): 2117, np.int64(2): 2117}
#
# Training CNN-RNN model...
# Epoch 1/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 29s 78ms/step - accuracy: 0.3638 - loss: 1.7790 - val_accuracy: 0.3973 - val_loss: 1.2038 - learning_rate: 0.0010
# Epoch 2/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.4393 - loss: 1.2870 - val_accuracy: 0.5124 - val_loss: 1.0202 - learning_rate: 0.0010
# Epoch 3/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.4651 - loss: 1.1577 - val_accuracy: 0.5378 - val_loss: 0.9895 - learning_rate: 0.0010
# Epoch 4/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.4950 - loss: 1.0946 - val_accuracy: 0.5396 - val_loss: 1.0118 - learning_rate: 0.0010
# Epoch 5/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5224 - loss: 1.0539 - val_accuracy: 0.5502 - val_loss: 1.0034 - learning_rate: 0.0010
# Epoch 6/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5256 - loss: 1.0223 - val_accuracy: 0.5419 - val_loss: 0.9514 - learning_rate: 0.0010
# Epoch 7/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5414 - loss: 1.0034 - val_accuracy: 0.5620 - val_loss: 1.1712 - learning_rate: 0.0010
# Epoch 8/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5542 - loss: 0.9812 - val_accuracy: 0.4693 - val_loss: 1.1273 - learning_rate: 0.0010
# Epoch 9/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5988 - loss: 0.8968 - val_accuracy: 0.4711 - val_loss: 1.3318 - learning_rate: 0.0010
# Epoch 10/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6264 - loss: 0.8354 - val_accuracy: 0.4835 - val_loss: 1.5386 - learning_rate: 0.0010
# Epoch 11/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6529 - loss: 0.7743 - val_accuracy: 0.5661 - val_loss: 2.4128 - learning_rate: 0.0010
# Epoch 12/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6722 - loss: 0.7166 - val_accuracy: 0.5679 - val_loss: 3.5148 - learning_rate: 5.0000e-04
# Epoch 13/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6850 - loss: 0.6978 - val_accuracy: 0.6919 - val_loss: 0.5979 - learning_rate: 5.0000e-04
# Epoch 14/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6885 - loss: 0.6712 - val_accuracy: 0.5124 - val_loss: 2.2730 - learning_rate: 5.0000e-04
# Epoch 15/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7010 - loss: 0.6493 - val_accuracy: 0.6051 - val_loss: 1.4082 - learning_rate: 5.0000e-04
# Epoch 16/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7067 - loss: 0.6324 - val_accuracy: 0.5012 - val_loss: 2.1483 - learning_rate: 5.0000e-04
# Epoch 17/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7066 - loss: 0.6422 - val_accuracy: 0.7373 - val_loss: 0.5617 - learning_rate: 5.0000e-04
# Epoch 18/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7170 - loss: 0.6104 - val_accuracy: 0.5661 - val_loss: 1.3439 - learning_rate: 5.0000e-04
# Epoch 19/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7144 - loss: 0.6142 - val_accuracy: 0.6741 - val_loss: 0.7922 - learning_rate: 5.0000e-04
# Epoch 20/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7343 - loss: 0.5851 - val_accuracy: 0.6004 - val_loss: 6.0902 - learning_rate: 5.0000e-04
# Epoch 21/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7358 - loss: 0.5712 - val_accuracy: 0.6192 - val_loss: 2.2605 - learning_rate: 5.0000e-04
# Epoch 22/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7567 - loss: 0.5483 - val_accuracy: 0.6157 - val_loss: 1.6428 - learning_rate: 5.0000e-04
# Epoch 23/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7702 - loss: 0.5259 - val_accuracy: 0.7314 - val_loss: 0.6749 - learning_rate: 2.5000e-04
# Epoch 24/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7998 - loss: 0.4778 - val_accuracy: 0.7349 - val_loss: 0.8454 - learning_rate: 2.5000e-04
# Epoch 25/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8264 - loss: 0.4332 - val_accuracy: 0.6287 - val_loss: 7.0464 - learning_rate: 2.5000e-04
# Epoch 26/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8265 - loss: 0.4265 - val_accuracy: 0.6517 - val_loss: 2.0579 - learning_rate: 2.5000e-04
# Epoch 27/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8384 - loss: 0.4096 - val_accuracy: 0.7113 - val_loss: 1.2237 - learning_rate: 2.5000e-04
# Epoch 28/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8599 - loss: 0.3562 - val_accuracy: 0.6352 - val_loss: 5.5491 - learning_rate: 1.2500e-04
# Epoch 29/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8720 - loss: 0.3414 - val_accuracy: 0.6600 - val_loss: 2.1656 - learning_rate: 1.2500e-04
# Epoch 30/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8874 - loss: 0.3234 - val_accuracy: 0.7780 - val_loss: 0.7278 - learning_rate: 1.2500e-04
# Epoch 31/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8821 - loss: 0.3202 - val_accuracy: 0.7527 - val_loss: 0.9850 - learning_rate: 1.2500e-04
# Epoch 32/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8973 - loss: 0.2910 - val_accuracy: 0.8766 - val_loss: 0.4326 - learning_rate: 1.2500e-04
# Epoch 33/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8887 - loss: 0.3069 - val_accuracy: 0.6860 - val_loss: 2.1972 - learning_rate: 1.2500e-04
# Epoch 34/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8932 - loss: 0.2979 - val_accuracy: 0.6989 - val_loss: 1.8151 - learning_rate: 1.2500e-04
# Epoch 35/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9055 - loss: 0.2639 - val_accuracy: 0.6423 - val_loss: 5.1492 - learning_rate: 1.2500e-04
# Epoch 36/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9080 - loss: 0.2720 - val_accuracy: 0.8861 - val_loss: 0.3836 - learning_rate: 1.2500e-04
# Epoch 37/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9097 - loss: 0.2436 - val_accuracy: 0.6523 - val_loss: 3.5373 - learning_rate: 1.2500e-04
# Epoch 38/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9125 - loss: 0.2490 - val_accuracy: 0.8955 - val_loss: 0.3442 - learning_rate: 1.2500e-04
# Epoch 39/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9144 - loss: 0.2532 - val_accuracy: 0.7893 - val_loss: 0.7847 - learning_rate: 1.2500e-04
# Epoch 40/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9145 - loss: 0.2416 - val_accuracy: 0.7898 - val_loss: 0.9109 - learning_rate: 1.2500e-04
# Epoch 41/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9247 - loss: 0.2404 - val_accuracy: 0.6576 - val_loss: 3.5021 - learning_rate: 1.2500e-04
# Epoch 42/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9193 - loss: 0.2281 - val_accuracy: 0.8099 - val_loss: 0.7564 - learning_rate: 1.2500e-04
# Epoch 43/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9243 - loss: 0.2191 - val_accuracy: 0.7249 - val_loss: 1.7375 - learning_rate: 1.2500e-04
# Epoch 44/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9263 - loss: 0.2185 - val_accuracy: 0.7237 - val_loss: 1.7248 - learning_rate: 6.2500e-05
# Epoch 45/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9275 - loss: 0.2065 - val_accuracy: 0.7379 - val_loss: 1.6458 - learning_rate: 6.2500e-05
# Epoch 46/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9322 - loss: 0.1988 - val_accuracy: 0.8884 - val_loss: 0.3886 - learning_rate: 6.2500e-05
# Epoch 47/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9405 - loss: 0.1948 - val_accuracy: 0.8571 - val_loss: 0.4330 - learning_rate: 6.2500e-05
# Epoch 48/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9336 - loss: 0.1910 - val_accuracy: 0.8778 - val_loss: 0.4053 - learning_rate: 6.2500e-05
# Epoch 49/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9323 - loss: 0.1929 - val_accuracy: 0.8530 - val_loss: 0.4846 - learning_rate: 3.1250e-05
# Epoch 50/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9381 - loss: 0.1759 - val_accuracy: 0.8388 - val_loss: 0.5556 - learning_rate: 3.1250e-05
# Fold 3 Results:
#   Accuracy:  0.8183
#   F1-Score:  0.8132
#   Time:      8.58 minutes
#   🏆 New best model! Accuracy: 0.8183
#
# ============================================================
# FOLD 4/5
# ============================================================
# Train shape: (4205, 1000, 12), Test shape: (1051, 1000, 12)
# Train distribution: {np.int64(2): 2117, np.int64(3): 963, np.int64(0): 957, np.int64(1): 168}
#
# === Balancing dengan GAN ===
#   Kelas 0: 957 samples -> perlu 1160 samples baru
#   🏗️  Training GAN untuk kelas 0...
#   GAN Epoch 100/500 - D Loss: 1.0731, G Loss: 0.1269
#   GAN Epoch 200/500 - D Loss: 1.6888, G Loss: 0.0706
#   GAN Epoch 300/500 - D Loss: 2.3292, G Loss: 0.0492
#   GAN Epoch 400/500 - D Loss: 2.8698, G Loss: 0.0378
#   GAN Epoch 500/500 - D Loss: 3.2854, G Loss: 0.0308
#   ✅ Generated 1160 samples untuk kelas 0
#   Kelas 1: 168 samples -> perlu 1949 samples baru
#   🏗️  Training GAN untuk kelas 1...
#   GAN Epoch 100/500 - D Loss: 1.0374, G Loss: 0.1585
#   GAN Epoch 200/500 - D Loss: 1.6280, G Loss: 0.0883
#   GAN Epoch 300/500 - D Loss: 2.1960, G Loss: 0.0617
#   GAN Epoch 400/500 - D Loss: 2.6923, G Loss: 0.0474
#   GAN Epoch 500/500 - D Loss: 3.0854, G Loss: 0.0386
#   ✅ Generated 1949 samples untuk kelas 1
#   Kelas 3: 963 samples -> perlu 1154 samples baru
#   🏗️  Training GAN untuk kelas 3...
#   GAN Epoch 100/500 - D Loss: 1.0649, G Loss: 0.1898
#   GAN Epoch 200/500 - D Loss: 1.6472, G Loss: 0.1068
#   GAN Epoch 300/500 - D Loss: 2.2503, G Loss: 0.0748
#   GAN Epoch 400/500 - D Loss: 2.7636, G Loss: 0.0580
#   GAN Epoch 500/500 - D Loss: 3.1650, G Loss: 0.0476
#   ✅ Generated 1154 samples untuk kelas 3
#   Dataset setelah balancing: (8468, 1000, 12)
#   Distribusi kelas: {np.int64(3): 2117, np.int64(0): 2117, np.int64(2): 2117, np.int64(1): 2117}
#
# Training CNN-RNN model...
# Epoch 1/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 29s 78ms/step - accuracy: 0.3878 - loss: 1.6838 - val_accuracy: 0.5289 - val_loss: 1.0630 - learning_rate: 0.0010
# Epoch 2/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.4439 - loss: 1.2898 - val_accuracy: 0.5413 - val_loss: 1.0100 - learning_rate: 0.0010
# Epoch 3/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.4636 - loss: 1.1563 - val_accuracy: 0.5407 - val_loss: 1.0022 - learning_rate: 0.0010
# Epoch 4/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.4895 - loss: 1.0992 - val_accuracy: 0.5561 - val_loss: 0.9690 - learning_rate: 0.0010
# Epoch 5/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5223 - loss: 1.0484 - val_accuracy: 0.5561 - val_loss: 0.9546 - learning_rate: 0.0010
# Epoch 6/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5130 - loss: 1.0486 - val_accuracy: 0.5632 - val_loss: 0.9524 - learning_rate: 0.0010
# Epoch 7/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5339 - loss: 1.0069 - val_accuracy: 0.5602 - val_loss: 0.9601 - learning_rate: 0.0010
# Epoch 8/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5412 - loss: 1.0021 - val_accuracy: 0.5537 - val_loss: 0.9478 - learning_rate: 0.0010
# Epoch 9/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5419 - loss: 0.9945 - val_accuracy: 0.5685 - val_loss: 0.9246 - learning_rate: 0.0010
# Epoch 10/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5468 - loss: 0.9796 - val_accuracy: 0.5272 - val_loss: 0.9610 - learning_rate: 0.0010
# Epoch 11/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5575 - loss: 0.9636 - val_accuracy: 0.4817 - val_loss: 2.0052 - learning_rate: 0.0010
# Epoch 12/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5688 - loss: 0.9506 - val_accuracy: 0.4835 - val_loss: 1.5703 - learning_rate: 0.0010
# Epoch 13/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6037 - loss: 0.8853 - val_accuracy: 0.4723 - val_loss: 1.3551 - learning_rate: 0.0010
# Epoch 14/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6173 - loss: 0.8546 - val_accuracy: 0.4728 - val_loss: 3.9593 - learning_rate: 0.0010
# Epoch 15/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6588 - loss: 0.7898 - val_accuracy: 0.4805 - val_loss: 1.5831 - learning_rate: 5.0000e-04
# Epoch 16/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6898 - loss: 0.7194 - val_accuracy: 0.4947 - val_loss: 1.6198 - learning_rate: 5.0000e-04
# Epoch 17/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7212 - loss: 0.6790 - val_accuracy: 0.5077 - val_loss: 1.4642 - learning_rate: 5.0000e-04
# Epoch 18/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7309 - loss: 0.6612 - val_accuracy: 0.6393 - val_loss: 0.6926 - learning_rate: 5.0000e-04
# Epoch 19/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7428 - loss: 0.6319 - val_accuracy: 0.5012 - val_loss: 4.0776 - learning_rate: 5.0000e-04
# Epoch 20/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7566 - loss: 0.6136 - val_accuracy: 0.5030 - val_loss: 2.9887 - learning_rate: 5.0000e-04
# Epoch 21/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7536 - loss: 0.6087 - val_accuracy: 0.6960 - val_loss: 0.6772 - learning_rate: 5.0000e-04
# Epoch 22/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7693 - loss: 0.5807 - val_accuracy: 0.5077 - val_loss: 2.1736 - learning_rate: 5.0000e-04
# Epoch 23/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7827 - loss: 0.5727 - val_accuracy: 0.5148 - val_loss: 5.1420 - learning_rate: 5.0000e-04
# Epoch 24/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7907 - loss: 0.5428 - val_accuracy: 0.6659 - val_loss: 0.7351 - learning_rate: 5.0000e-04
# Epoch 25/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7964 - loss: 0.5284 - val_accuracy: 0.5366 - val_loss: 3.0326 - learning_rate: 5.0000e-04
# Epoch 26/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7988 - loss: 0.5153 - val_accuracy: 0.5331 - val_loss: 2.1126 - learning_rate: 5.0000e-04
# Epoch 27/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8270 - loss: 0.4586 - val_accuracy: 0.5927 - val_loss: 1.3189 - learning_rate: 2.5000e-04
# Epoch 28/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8281 - loss: 0.4367 - val_accuracy: 0.7633 - val_loss: 0.5837 - learning_rate: 2.5000e-04
# Epoch 29/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8441 - loss: 0.4118 - val_accuracy: 0.6311 - val_loss: 0.9914 - learning_rate: 2.5000e-04
# Epoch 30/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8491 - loss: 0.4012 - val_accuracy: 0.7674 - val_loss: 0.5743 - learning_rate: 2.5000e-04
# Epoch 31/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8503 - loss: 0.4087 - val_accuracy: 0.5626 - val_loss: 2.5900 - learning_rate: 2.5000e-04
# Epoch 32/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8563 - loss: 0.3850 - val_accuracy: 0.5909 - val_loss: 1.9352 - learning_rate: 2.5000e-04
# Epoch 33/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8607 - loss: 0.3632 - val_accuracy: 0.7710 - val_loss: 0.5545 - learning_rate: 2.5000e-04
# Epoch 34/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8639 - loss: 0.3568 - val_accuracy: 0.6865 - val_loss: 0.8733 - learning_rate: 2.5000e-04
# Epoch 35/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8509 - loss: 0.3821 - val_accuracy: 0.5561 - val_loss: 3.7808 - learning_rate: 2.5000e-04
# Epoch 36/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8713 - loss: 0.3513 - val_accuracy: 0.5797 - val_loss: 1.9622 - learning_rate: 2.5000e-04
# Epoch 37/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8656 - loss: 0.3543 - val_accuracy: 0.5708 - val_loss: 2.8562 - learning_rate: 2.5000e-04
# Epoch 38/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8720 - loss: 0.3391 - val_accuracy: 0.8577 - val_loss: 0.4049 - learning_rate: 2.5000e-04
# Epoch 39/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8742 - loss: 0.3264 - val_accuracy: 0.5508 - val_loss: 4.2913 - learning_rate: 2.5000e-04
# Epoch 40/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8805 - loss: 0.3330 - val_accuracy: 0.6334 - val_loss: 1.4959 - learning_rate: 2.5000e-04
# Epoch 41/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8876 - loss: 0.3072 - val_accuracy: 0.6175 - val_loss: 1.3947 - learning_rate: 2.5000e-04
# Epoch 42/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8787 - loss: 0.3135 - val_accuracy: 0.6340 - val_loss: 1.4132 - learning_rate: 2.5000e-04
# Epoch 43/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8911 - loss: 0.2978 - val_accuracy: 0.5596 - val_loss: 4.5704 - learning_rate: 2.5000e-04
# Epoch 44/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8946 - loss: 0.2846 - val_accuracy: 0.9038 - val_loss: 0.2854 - learning_rate: 1.2500e-04
# Epoch 45/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9077 - loss: 0.2531 - val_accuracy: 0.5862 - val_loss: 2.6046 - learning_rate: 1.2500e-04
# Epoch 46/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9047 - loss: 0.2651 - val_accuracy: 0.5744 - val_loss: 3.9760 - learning_rate: 1.2500e-04
# Epoch 47/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9025 - loss: 0.2559 - val_accuracy: 0.7196 - val_loss: 0.8130 - learning_rate: 1.2500e-04
# Epoch 48/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9119 - loss: 0.2520 - val_accuracy: 0.6198 - val_loss: 1.9227 - learning_rate: 1.2500e-04
# Epoch 49/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9034 - loss: 0.2539 - val_accuracy: 0.6570 - val_loss: 1.3016 - learning_rate: 1.2500e-04
# Epoch 50/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9199 - loss: 0.2223 - val_accuracy: 0.5862 - val_loss: 3.2550 - learning_rate: 6.2500e-05
# Fold 4 Results:
#   Accuracy:  0.8735
#   F1-Score:  0.8721
#   Time:      8.57 minutes
#   🏆 New best model! Accuracy: 0.8735
#
# ============================================================
# FOLD 5/5
# ============================================================
# Train shape: (4205, 1000, 12), Test shape: (1051, 1000, 12)
# Train distribution: {np.int64(2): 2117, np.int64(3): 963, np.int64(0): 957, np.int64(1): 168}
#
# === Balancing dengan GAN ===
#   Kelas 0: 957 samples -> perlu 1160 samples baru
#   🏗️  Training GAN untuk kelas 0...
#   GAN Epoch 100/500 - D Loss: 1.0955, G Loss: 0.1494
#   GAN Epoch 200/500 - D Loss: 1.6935, G Loss: 0.0831
#   GAN Epoch 300/500 - D Loss: 2.2977, G Loss: 0.0579
#   GAN Epoch 400/500 - D Loss: 2.8118, G Loss: 0.0446
#   GAN Epoch 500/500 - D Loss: 3.2278, G Loss: 0.0363
#   ✅ Generated 1160 samples untuk kelas 0
#   Kelas 1: 168 samples -> perlu 1949 samples baru
#   🏗️  Training GAN untuk kelas 1...
#   GAN Epoch 100/500 - D Loss: 1.0488, G Loss: 0.1618
#   GAN Epoch 200/500 - D Loss: 1.6678, G Loss: 0.0902
#   GAN Epoch 300/500 - D Loss: 2.2812, G Loss: 0.0631
#   GAN Epoch 400/500 - D Loss: 2.7963, G Loss: 0.0484
#   GAN Epoch 500/500 - D Loss: 3.2049, G Loss: 0.0393
#   ✅ Generated 1949 samples untuk kelas 1
#   Kelas 3: 963 samples -> perlu 1154 samples baru
#   🏗️  Training GAN untuk kelas 3...
#   GAN Epoch 100/500 - D Loss: 1.0672, G Loss: 0.1149
#   GAN Epoch 200/500 - D Loss: 1.7103, G Loss: 0.0647
#   GAN Epoch 300/500 - D Loss: 2.3978, G Loss: 0.0452
#   GAN Epoch 400/500 - D Loss: 2.9472, G Loss: 0.0347
#   GAN Epoch 500/500 - D Loss: 3.3658, G Loss: 0.0282
#   ✅ Generated 1154 samples untuk kelas 3
#   Dataset setelah balancing: (8468, 1000, 12)
#   Distribusi kelas: {np.int64(2): 2117, np.int64(3): 2117, np.int64(0): 2117, np.int64(1): 2117}
#
# Training CNN-RNN model...
# Epoch 1/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 29s 78ms/step - accuracy: 0.3897 - loss: 1.7708 - val_accuracy: 0.5030 - val_loss: 1.0878 - learning_rate: 0.0010
# Epoch 2/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.4307 - loss: 1.3059 - val_accuracy: 0.4947 - val_loss: 1.0559 - learning_rate: 0.0010
# Epoch 3/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.4529 - loss: 1.1728 - val_accuracy: 0.5124 - val_loss: 1.0343 - learning_rate: 0.0010
# Epoch 4/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.4794 - loss: 1.0931 - val_accuracy: 0.5177 - val_loss: 1.0281 - learning_rate: 0.0010
# Epoch 5/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.5182 - loss: 1.0513 - val_accuracy: 0.5260 - val_loss: 1.0084 - learning_rate: 0.0010
# Epoch 6/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5246 - loss: 1.0363 - val_accuracy: 0.5248 - val_loss: 1.0012 - learning_rate: 0.0010
# Epoch 7/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5386 - loss: 1.0081 - val_accuracy: 0.5372 - val_loss: 0.9774 - learning_rate: 0.0010
# Epoch 8/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5485 - loss: 0.9956 - val_accuracy: 0.5419 - val_loss: 0.9725 - learning_rate: 0.0010
# Epoch 9/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5332 - loss: 0.9952 - val_accuracy: 0.5348 - val_loss: 0.9778 - learning_rate: 0.0010
# Epoch 10/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5528 - loss: 0.9708 - val_accuracy: 0.5419 - val_loss: 0.9680 - learning_rate: 0.0010
# Epoch 11/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5561 - loss: 0.9684 - val_accuracy: 0.5490 - val_loss: 0.9697 - learning_rate: 0.0010
# Epoch 12/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5627 - loss: 0.9612 - val_accuracy: 0.5543 - val_loss: 0.9432 - learning_rate: 0.0010
# Epoch 13/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5602 - loss: 0.9538 - val_accuracy: 0.5584 - val_loss: 0.9332 - learning_rate: 0.0010
# Epoch 14/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5581 - loss: 0.9448 - val_accuracy: 0.5626 - val_loss: 0.9313 - learning_rate: 0.0010
# Epoch 15/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5705 - loss: 0.9324 - val_accuracy: 0.5549 - val_loss: 0.9522 - learning_rate: 0.0010
# Epoch 16/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5728 - loss: 0.9267 - val_accuracy: 0.5573 - val_loss: 0.9300 - learning_rate: 0.0010
# Epoch 17/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5752 - loss: 0.9233 - val_accuracy: 0.5584 - val_loss: 0.9285 - learning_rate: 0.0010
# Epoch 18/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5804 - loss: 0.9142 - val_accuracy: 0.5702 - val_loss: 0.9215 - learning_rate: 0.0010
# Epoch 19/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5806 - loss: 0.9072 - val_accuracy: 0.5602 - val_loss: 0.9438 - learning_rate: 0.0010
# Epoch 20/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5832 - loss: 0.8991 - val_accuracy: 0.5785 - val_loss: 0.9043 - learning_rate: 0.0010
# Epoch 21/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5891 - loss: 0.8873 - val_accuracy: 0.5732 - val_loss: 0.8979 - learning_rate: 0.0010
# Epoch 22/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5900 - loss: 0.8893 - val_accuracy: 0.5702 - val_loss: 0.9352 - learning_rate: 0.0010
# Epoch 23/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5928 - loss: 0.8737 - val_accuracy: 0.5803 - val_loss: 0.8831 - learning_rate: 0.0010
# Epoch 24/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6091 - loss: 0.8621 - val_accuracy: 0.5844 - val_loss: 0.8921 - learning_rate: 0.0010
# Epoch 25/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6009 - loss: 0.8603 - val_accuracy: 0.5909 - val_loss: 0.8632 - learning_rate: 0.0010
# Epoch 26/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6117 - loss: 0.8401 - val_accuracy: 0.5809 - val_loss: 0.8887 - learning_rate: 0.0010
# Epoch 27/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6135 - loss: 0.8415 - val_accuracy: 0.5874 - val_loss: 0.9263 - learning_rate: 0.0010
# Epoch 28/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6195 - loss: 0.8339 - val_accuracy: 0.6021 - val_loss: 0.8663 - learning_rate: 0.0010
# Epoch 29/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6239 - loss: 0.8248 - val_accuracy: 0.6004 - val_loss: 0.8649 - learning_rate: 0.0010
# Epoch 30/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6237 - loss: 0.8201 - val_accuracy: 0.6015 - val_loss: 0.8509 - learning_rate: 0.0010
# Epoch 31/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6309 - loss: 0.8159 - val_accuracy: 0.6051 - val_loss: 0.8758 - learning_rate: 0.0010
# Epoch 32/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6310 - loss: 0.7935 - val_accuracy: 0.5573 - val_loss: 1.1997 - learning_rate: 0.0010
# Epoch 33/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6264 - loss: 0.8194 - val_accuracy: 0.5921 - val_loss: 0.8720 - learning_rate: 0.0010
# Epoch 34/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6266 - loss: 0.8136 - val_accuracy: 0.4026 - val_loss: 1.4618 - learning_rate: 0.0010
# Epoch 35/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6343 - loss: 0.7935 - val_accuracy: 0.6128 - val_loss: 0.8282 - learning_rate: 0.0010
# Epoch 36/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6491 - loss: 0.7566 - val_accuracy: 0.5313 - val_loss: 0.8950 - learning_rate: 0.0010
# Epoch 37/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6493 - loss: 0.7666 - val_accuracy: 0.6216 - val_loss: 0.8129 - learning_rate: 0.0010
# Epoch 38/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6427 - loss: 0.7658 - val_accuracy: 0.5224 - val_loss: 0.8903 - learning_rate: 0.0010
# Epoch 39/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6414 - loss: 0.7707 - val_accuracy: 0.6175 - val_loss: 0.8018 - learning_rate: 0.0010
# Epoch 40/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6526 - loss: 0.7422 - val_accuracy: 0.4227 - val_loss: 1.5166 - learning_rate: 0.0010
# Epoch 41/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6574 - loss: 0.7289 - val_accuracy: 0.6269 - val_loss: 0.9066 - learning_rate: 0.0010
# Epoch 42/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6669 - loss: 0.7216 - val_accuracy: 0.6098 - val_loss: 1.0926 - learning_rate: 0.0010
# Epoch 43/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6875 - loss: 0.7060 - val_accuracy: 0.4622 - val_loss: 1.7302 - learning_rate: 0.0010
# Epoch 44/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6948 - loss: 0.6800 - val_accuracy: 0.7397 - val_loss: 0.6474 - learning_rate: 0.0010
# Epoch 45/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7313 - loss: 0.6142 - val_accuracy: 0.6222 - val_loss: 1.6020 - learning_rate: 0.0010
# Epoch 46/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7334 - loss: 0.6005 - val_accuracy: 0.6240 - val_loss: 1.4105 - learning_rate: 0.0010
# Epoch 47/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7512 - loss: 0.5542 - val_accuracy: 0.6783 - val_loss: 0.9641 - learning_rate: 0.0010
# Epoch 48/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7722 - loss: 0.5223 - val_accuracy: 0.4044 - val_loss: 2.7232 - learning_rate: 0.0010
# Epoch 49/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7782 - loss: 0.5213 - val_accuracy: 0.6942 - val_loss: 0.6883 - learning_rate: 0.0010
# Epoch 50/50
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.8051 - loss: 0.4676 - val_accuracy: 0.5702 - val_loss: 2.3502 - learning_rate: 5.0000e-04
# Fold 5 Results:
#   Accuracy:  0.8154
#   F1-Score:  0.7989
#   Time:      8.58 minutes
#
# ============================================================
# GENERATING 13 OUTPUT FILES...
# ============================================================
# ✓ 1. Confusion Matrix saved
# ✓ 2. ROC Curve saved
# ✓ 3. Learning Curve saved
# ✓ 4. t-SNE saved
# Attention map plot error: where size (64) does not match 'x' size (1000)
# ✓ 5. Attention Maps saved
# ✓ 6. Fold Comparison saved
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✓ 7. Consistency Plot saved
# ✓ 8. Best Model saved
# ✓ 9. CV Results CSV saved
# ✓ 10. Tabel 1 saved
# ✓ 11. Tabel 2 saved
# ✓ 12. Tabel 3 saved
# ✓ 13. Tabel 4 saved
#
# ============================================================
# ALL 13 OUTPUTS COMPLETED FOR CNN_RNN_GAN!
# ============================================================
# Model: CNN-RNN with Attention and GAN
# Best Accuracy: 0.8735 (Fold 4)
# Mean Accuracy: 0.8187 ± 0.0326
# Mean F1-Score: 0.8063
# Total Time: 0.70 hours
#
# 📁 13 Output Files Generated:
#   1. FINAL_CM_CNN_RNN_GAN.png           - Confusion Matrix
#   2. FINAL_ROC_CNN_RNN_GAN.png          - ROC Curve
#   3. FINAL_Learning_Curve_CNN_RNN_GAN.png - Learning Curve
#   4. FINAL_TSNE_CNN_RNN_GAN.png         - t-SNE Visualization
#   5. FINAL_Attention_CNN_RNN_GAN.png    - Attention Maps
#   6. FINAL_Fold_Comparison_CNN_RNN_GAN.png - Fold Comparison
#   7. FINAL_Consistency_CNN_RNN_GAN.png  - Consistency Plot
#   8. FINAL_best_model_CNN_RNN_GAN.h5    - Best Model
#   9. FINAL_CV_CNN_RNN_GAN.csv           - CV Results
#  10. FINAL_Tabel1_CNN_RNN_GAN.csv       - Summary Metrics
#  11. FINAL_Tabel2_CNN_RNN_GAN.csv       - Per Class Metrics
#  12. FINAL_Tabel3_CNN_RNN_GAN.csv       - Efficiency Analysis
#  13. FINAL_Tabel4_CNN_RNN_GAN.csv       - Consistency Analysis
#
# ✅ CNN-RNN with GAN Implementation COMPLETE!
